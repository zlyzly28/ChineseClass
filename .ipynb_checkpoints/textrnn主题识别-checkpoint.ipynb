# %%
# coding: UTF-8
import os
import torch
import numpy as np
import pickle as pkl
from tqdm import tqdm
import time
from datetime import timedelta
import time
import torch
import numpy as np
from train_eval import train, init_network
from importlib import import_module
import argparse
dataset = 'Newtrain'  # 数据集

# 搜狗新闻:embedding_SougouNews.npz, 腾讯:embedding_Tencent.npz, 随机初始化:random
embedding = 'embedding_Newtrain_300.npz'

model_name = 'TextRNN'  # 'TextRCNN'  # TextCNN, TextRNN, FastText, TextRCNN, TextRNN_Att, DPCNN, Transformer


x = import_module('models.' + model_name)
config = x.Config(dataset, embedding)
config.pad_size = 64

MAX_VOCAB_SIZE = 20000  # 词表长度限制
UNK, PAD = '<UNK>', '<PAD>'  # 未知字，padding符号
ues_word = True
from utils import get_time_dif, build_vocab, build_dataset2, build_iterator2


vocab, train, test = build_dataset2(config, ues_word)
# Out:
# Vocab size: 12678
# 8000it [00:00, 67966.46it/s]
# 2653it [00:00, 67981.53it/s]

# %%
import torch.nn.functional as F
import torch.nn as nn
from model_myself import *

train_iter = build_iterator2(train, config)
test_iter = build_iterator2(test, config)
# train_iter.__next__()

config.n_vocab = len(vocab)
if model_name == 'TextRNN':
    model = text_rnn(config).to(config.device)
if model_name == 'TextCNN':
    model = text_cnn(config).to(config.device)
    
if model_name != 'Transformer':
    init_network(model)
print(model.parameters)
# Out:
# <bound method Module.parameters of text_rnn(
#   (embedding): Embedding(12678, 300)
#   (lstm): LSTM(300, 128, num_layers=2, batch_first=True, dropout=0.5, bidirectional=True)
#   (fc): Linear(in_features=256, out_features=10, bias=True)
# )>

# %%
import numpy as np
import torch
import json
import torch.nn as nn
import torch.nn.functional as F
from sklearn import metrics
import time
from utils import get_time_dif
from tensorboardX import SummaryWriter
from collections import defaultdict
from train_eval import train_zhuti

train_zhuti(config, model, train_iter, test_iter)
# Out:
# Epoch [1/10]
# Iter:      0,  Train Loss:  0.69,  Train Acc: 49.61%,  Val Loss:  0.61,  Val Acc: 11.20%,  Time: 0:00:00 *improve
# Iter:      0,  Train precision: 63.77%,  Train recall: 55.12%,  Val precision: 5.60%,  Val recall: 50.00%,  Time: 0:00:00 *improve
# Iter:     10,  Train Loss:  0.42,  Train Acc: 84.69%,  Val Loss:  0.35,  Val Acc: 83.98%,  Time: 0:00:00 *improve
# Iter:     10,  Train precision: 50.00%,  Train recall: 42.34%,  Val precision: 59.75%,  Val recall: 59.77%,  Time: 0:00:00 *improve
# Iter:     20,  Train Loss:  0.39,  Train Acc: 86.64%,  Val Loss:  0.34,  Val Acc: 84.92%,  Time: 0:00:01 *improve
# Iter:     20,  Train precision: 50.00%,  Train recall: 43.32%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:01 *improve
# Iter:     30,  Train Loss:  0.39,  Train Acc: 87.11%,  Val Loss:  0.35,  Val Acc: 88.80%,  Time: 0:00:01
# Iter:     30,  Train precision: 50.00%,  Train recall: 43.55%,  Val precision: 44.40%,  Val recall: 50.00%,  Time: 0:00:01
# Iter:     40,  Train Loss:  0.29,  Train Acc: 90.00%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:01 *improve
# Iter:     40,  Train precision: 50.00%,  Train recall: 45.00%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:01 *improve
# Iter:     50,  Train Loss:  0.39,  Train Acc: 86.64%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:01 *improve
# Iter:     50,  Train precision: 50.00%,  Train recall: 43.32%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:01 *improve
# Iter:     60,  Train Loss:  0.34,  Train Acc: 87.73%,  Val Loss:  0.33,  Val Acc: 88.68%,  Time: 0:00:02
# Iter:     60,  Train precision: 50.00%,  Train recall: 43.87%,  Val precision: 64.28%,  Val recall: 50.80%,  Time: 0:00:02
# Epoch [2/10]
# Iter:     70,  Train Loss:  0.29,  Train Acc: 89.61%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:02
# Iter:     70,  Train precision: 50.00%,  Train recall: 44.80%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:02
# Iter:     80,  Train Loss:  0.33,  Train Acc: 88.44%,  Val Loss:  0.34,  Val Acc: 84.92%,  Time: 0:00:02
# Iter:     80,  Train precision: 51.53%,  Train recall: 59.68%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:02
# Iter:     90,  Train Loss:  0.32,  Train Acc: 89.38%,  Val Loss:  0.33,  Val Acc: 88.68%,  Time: 0:00:03
# Iter:     90,  Train precision: 50.00%,  Train recall: 44.69%,  Val precision: 64.28%,  Val recall: 50.80%,  Time: 0:00:03
# Iter:    100,  Train Loss:  0.34,  Train Acc: 87.97%,  Val Loss:  0.33,  Val Acc: 88.80%,  Time: 0:00:03
# Iter:    100,  Train precision: 50.00%,  Train recall: 43.98%,  Val precision: 44.40%,  Val recall: 50.00%,  Time: 0:00:03
# Iter:    110,  Train Loss:  0.36,  Train Acc: 87.89%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:03 *improve
# Iter:    110,  Train precision: 50.00%,  Train recall: 43.95%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:03 *improve
# Iter:    120,  Train Loss:  0.35,  Train Acc: 87.97%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:03 *improve
# Iter:    120,  Train precision: 50.00%,  Train recall: 43.98%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:03 *improve
# Epoch [3/10]
# Iter:    130,  Train Loss:  0.36,  Train Acc: 87.66%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:04
# Iter:    130,  Train precision: 50.00%,  Train recall: 43.83%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:04
# Iter:    140,  Train Loss:  0.32,  Train Acc: 88.36%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:04
# Iter:    140,  Train precision: 50.00%,  Train recall: 44.18%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:04
# Iter:    150,  Train Loss:  0.31,  Train Acc: 89.22%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:04
# Iter:    150,  Train precision: 50.00%,  Train recall: 44.61%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:04
# Iter:    160,  Train Loss:  0.41,  Train Acc: 86.88%,  Val Loss:  0.33,  Val Acc: 88.70%,  Time: 0:00:04
# Iter:    160,  Train precision: 50.00%,  Train recall: 43.44%,  Val precision: 64.47%,  Val recall: 50.71%,  Time: 0:00:04
# Iter:    170,  Train Loss:  0.35,  Train Acc: 87.81%,  Val Loss:  0.33,  Val Acc: 88.68%,  Time: 0:00:05
# Iter:    170,  Train precision: 50.00%,  Train recall: 43.91%,  Val precision: 64.28%,  Val recall: 50.80%,  Time: 0:00:05
# Iter:    180,  Train Loss:  0.32,  Train Acc: 88.44%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:05 *improve
# Iter:    180,  Train precision: 50.00%,  Train recall: 44.22%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:05 *improve
# Epoch [4/10]
# Iter:    190,  Train Loss:  0.31,  Train Acc: 89.53%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:05
# Iter:    190,  Train precision: 50.00%,  Train recall: 44.77%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:05
# Iter:    200,  Train Loss:  0.26,  Train Acc: 88.75%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:05
# Iter:    200,  Train precision: 50.00%,  Train recall: 44.38%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:05
# Iter:    210,  Train Loss:  0.39,  Train Acc: 86.88%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:06
# Iter:    210,  Train precision: 50.21%,  Train recall: 60.17%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:06
# Iter:    220,  Train Loss:  0.36,  Train Acc: 87.66%,  Val Loss:  0.33,  Val Acc: 88.68%,  Time: 0:00:06
# Iter:    220,  Train precision: 50.00%,  Train recall: 43.83%,  Val precision: 64.28%,  Val recall: 50.80%,  Time: 0:00:06
# Iter:    230,  Train Loss:  0.28,  Train Acc: 90.00%,  Val Loss:  0.33,  Val Acc: 88.68%,  Time: 0:00:06
# Iter:    230,  Train precision: 50.00%,  Train recall: 45.00%,  Val precision: 64.28%,  Val recall: 50.80%,  Time: 0:00:06
# Iter:    240,  Train Loss:   0.4,  Train Acc: 84.45%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:06
# Iter:    240,  Train precision: 50.00%,  Train recall: 42.23%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:06
# Iter:    250,  Train Loss:  0.33,  Train Acc: 87.81%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:07
# Iter:    250,  Train precision: 50.00%,  Train recall: 43.91%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:07
# Epoch [5/10]
# Iter:    260,  Train Loss:  0.32,  Train Acc: 88.52%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:07
# Iter:    260,  Train precision: 50.00%,  Train recall: 44.26%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:07
# Iter:    270,  Train Loss:  0.36,  Train Acc: 86.64%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:07
# Iter:    270,  Train precision: 49.82%,  Train recall: 47.86%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:07
# Iter:    280,  Train Loss:  0.33,  Train Acc: 89.06%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:07
# Iter:    280,  Train precision: 50.00%,  Train recall: 44.53%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:07
# Iter:    290,  Train Loss:  0.36,  Train Acc: 87.03%,  Val Loss:  0.33,  Val Acc: 88.68%,  Time: 0:00:08
# Iter:    290,  Train precision: 50.00%,  Train recall: 43.52%,  Val precision: 64.28%,  Val recall: 50.80%,  Time: 0:00:08
# Iter:    300,  Train Loss:  0.38,  Train Acc: 86.95%,  Val Loss:  0.33,  Val Acc: 88.67%,  Time: 0:00:08
# Iter:    300,  Train precision: 50.00%,  Train recall: 43.48%,  Val precision: 64.10%,  Val recall: 50.84%,  Time: 0:00:08
# Iter:    310,  Train Loss:  0.35,  Train Acc: 88.05%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:08 *improve
# Iter:    310,  Train precision: 50.00%,  Train recall: 44.02%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:08 *improve
# Epoch [6/10]
# Iter:    320,  Train Loss:  0.34,  Train Acc: 88.05%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:08
# Iter:    320,  Train precision: 50.00%,  Train recall: 44.02%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:08
# Iter:    330,  Train Loss:  0.33,  Train Acc: 87.27%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:09
# Iter:    330,  Train precision: 49.87%,  Train recall: 43.74%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:09
# Iter:    340,  Train Loss:  0.32,  Train Acc: 89.38%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:09 *improve
# Iter:    340,  Train precision: 49.91%,  Train recall: 44.76%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:09 *improve
# Iter:    350,  Train Loss:  0.35,  Train Acc: 87.73%,  Val Loss:  0.33,  Val Acc: 88.68%,  Time: 0:00:09
# Iter:    350,  Train precision: 50.00%,  Train recall: 43.87%,  Val precision: 64.28%,  Val recall: 50.80%,  Time: 0:00:09
# Iter:    360,  Train Loss:  0.39,  Train Acc: 86.25%,  Val Loss:  0.33,  Val Acc: 88.68%,  Time: 0:00:09
# Iter:    360,  Train precision: 50.00%,  Train recall: 43.12%,  Val precision: 64.28%,  Val recall: 50.80%,  Time: 0:00:09
# Iter:    370,  Train Loss:  0.35,  Train Acc: 88.44%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:10
# Iter:    370,  Train precision: 50.00%,  Train recall: 44.22%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:10
# Epoch [7/10]
# Iter:    380,  Train Loss:  0.31,  Train Acc: 89.45%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:10
# Iter:    380,  Train precision: 50.00%,  Train recall: 44.73%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:10
# Iter:    390,  Train Loss:  0.27,  Train Acc: 89.45%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:10
# Iter:    390,  Train precision: 50.00%,  Train recall: 44.73%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:10
# Iter:    400,  Train Loss:  0.35,  Train Acc: 88.67%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:10
# Iter:    400,  Train precision: 50.00%,  Train recall: 44.34%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:10
# Iter:    410,  Train Loss:  0.39,  Train Acc: 86.80%,  Val Loss:  0.33,  Val Acc: 88.67%,  Time: 0:00:11
# Iter:    410,  Train precision: 50.00%,  Train recall: 43.40%,  Val precision: 64.03%,  Val recall: 50.82%,  Time: 0:00:11
# Iter:    420,  Train Loss:  0.28,  Train Acc: 90.00%,  Val Loss:  0.33,  Val Acc: 88.68%,  Time: 0:00:11
# Iter:    420,  Train precision: 50.00%,  Train recall: 45.00%,  Val precision: 64.28%,  Val recall: 50.80%,  Time: 0:00:11
# Iter:    430,  Train Loss:  0.44,  Train Acc: 85.08%,  Val Loss:  0.33,  Val Acc: 88.67%,  Time: 0:00:11
# Iter:    430,  Train precision: 33.33%,  Train recall: 28.36%,  Val precision: 64.17%,  Val recall: 50.85%,  Time: 0:00:11
# Iter:    440,  Train Loss:  0.33,  Train Acc: 88.91%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:11 *improve
# Iter:    440,  Train precision: 50.00%,  Train recall: 44.45%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:11 *improve
# Epoch [8/10]
# Iter:    450,  Train Loss:  0.47,  Train Acc: 83.20%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:12 *improve
# Iter:    450,  Train precision: 50.00%,  Train recall: 41.60%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:12 *improve
# Iter:    460,  Train Loss:  0.38,  Train Acc: 86.48%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:12
# Iter:    460,  Train precision: 50.32%,  Train recall: 55.94%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:12
# Iter:    470,  Train Loss:  0.36,  Train Acc: 87.89%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:12 *improve
# Iter:    470,  Train precision: 49.96%,  Train recall: 43.98%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:12 *improve
# Iter:    480,  Train Loss:  0.29,  Train Acc: 89.92%,  Val Loss:  0.33,  Val Acc: 88.68%,  Time: 0:00:12
# Iter:    480,  Train precision: 50.00%,  Train recall: 44.96%,  Val precision: 64.28%,  Val recall: 50.80%,  Time: 0:00:12
# Iter:    490,  Train Loss:  0.38,  Train Acc: 87.66%,  Val Loss:  0.33,  Val Acc: 88.68%,  Time: 0:00:13
# Iter:    490,  Train precision: 50.00%,  Train recall: 43.83%,  Val precision: 64.16%,  Val recall: 50.83%,  Time: 0:00:13
# Iter:    500,  Train Loss:  0.37,  Train Acc: 87.58%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:13 *improve
# Iter:    500,  Train precision: 50.00%,  Train recall: 43.79%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:13 *improve
# Epoch [9/10]
# Iter:    510,  Train Loss:  0.31,  Train Acc: 89.22%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:13
# Iter:    510,  Train precision: 50.00%,  Train recall: 44.61%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:13
# Iter:    520,  Train Loss:  0.33,  Train Acc: 88.44%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:13
# Iter:    520,  Train precision: 50.63%,  Train recall: 77.58%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:13
# Iter:    530,  Train Loss:   0.3,  Train Acc: 89.77%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:14
# Iter:    530,  Train precision: 50.38%,  Train recall: 94.88%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:14
# Iter:    540,  Train Loss:  0.37,  Train Acc: 86.02%,  Val Loss:  0.33,  Val Acc: 88.68%,  Time: 0:00:14
# Iter:    540,  Train precision: 50.00%,  Train recall: 43.01%,  Val precision: 64.28%,  Val recall: 50.80%,  Time: 0:00:14
# Iter:    550,  Train Loss:  0.35,  Train Acc: 88.75%,  Val Loss:  0.33,  Val Acc: 88.68%,  Time: 0:00:14
# Iter:    550,  Train precision: 50.00%,  Train recall: 44.38%,  Val precision: 64.28%,  Val recall: 50.80%,  Time: 0:00:14
# Iter:    560,  Train Loss:  0.36,  Train Acc: 87.58%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:14
# Iter:    560,  Train precision: 50.00%,  Train recall: 43.79%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:14
# Epoch [10/10]
# Iter:    570,  Train Loss:  0.36,  Train Acc: 87.81%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:15 *improve
# Iter:    570,  Train precision: 50.00%,  Train recall: 43.91%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:15 *improve
# Iter:    580,  Train Loss:  0.36,  Train Acc: 87.97%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:15
# Iter:    580,  Train precision: 50.32%,  Train recall: 93.98%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:15
# Iter:    590,  Train Loss:  0.35,  Train Acc: 88.67%,  Val Loss:  0.33,  Val Acc: 84.92%,  Time: 0:00:15
# Iter:    590,  Train precision: 50.26%,  Train recall: 61.07%,  Val precision: 60.76%,  Val recall: 59.74%,  Time: 0:00:15
# Iter:    600,  Train Loss:  0.39,  Train Acc: 86.88%,  Val Loss:  0.33,  Val Acc: 88.63%,  Time: 0:00:15
# Iter:    600,  Train precision: 50.00%,  Train recall: 43.44%,  Val precision: 63.54%,  Val recall: 50.96%,  Time: 0:00:15
# Iter:    610,  Train Loss:   0.3,  Train Acc: 90.00%,  Val Loss:  0.33,  Val Acc: 88.68%,  Time: 0:00:16
# Iter:    610,  Train precision: 50.00%,  Train recall: 45.00%,  Val precision: 64.28%,  Val recall: 50.80%,  Time: 0:00:16
# Iter:    620,  Train Loss:  0.35,  Train Acc: 89.45%,  Val Loss:  0.33,  Val Acc: 88.67%,  Time: 0:00:16
# Iter:    620,  Train precision: 50.00%,  Train recall: 44.73%,  Val precision: 64.17%,  Val recall: 50.85%,  Time: 0:00:16

# %%
import json

with open(config.log_path + '/train_dict.json', 'r', encoding='utf-8') as file:
    train_dict = json.load(file)
with open(config.log_path + '/test_dict.json', 'r', encoding='utf-8') as file:
    test_dict = json.load(file)

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(train_dict['train_loss']) + 1)
# 设置2行3列的子图布局，因为只有5个指标，所以最后一列会空出来
fig, axs = plt.subplots(2, 3, figsize=(10, 5), sharex=True)
# Flatten axs to easily iterate over it in case of more than one column
axs = axs.flatten()
for i, (key, values) in enumerate(train_dict.items()):
    axs[i].plot(epochs, values, marker='o', label=key)
    axs[i].set_ylabel(key)
    axs[i].set_title(key)  # 添加标题以替代右侧的图例，避免重叠
    axs[i].grid(True)

# 隐藏空的子图
for ax in axs[len(train_dict):]:
    ax.axis('off')
axs[-1].set_xlabel('Epochs')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # 调整布局，留出顶部空间给title或者避免紧凑
plt.show()

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(test_dict['dev_loss']) + 1)
# 设置2行3列的子图布局，因为只有5个指标，所以最后一列会空出来
fig, axs = plt.subplots(2, 3, figsize=(10, 5), sharex=True)
# Flatten axs to easily iterate over it in case of more than one column
axs = axs.flatten()
for i, (key, values) in enumerate(test_dict.items()):
    axs[i].plot(epochs, values, marker='o', label=key)
    axs[i].set_ylabel(key)
    axs[i].set_title(key)  # 添加标题以替代右侧的图例，避免重叠
    axs[i].grid(True)

# 隐藏空的子图
for ax in axs[len(test_dict):]:
    ax.axis('off')
axs[-1].set_xlabel('Epochs')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # 调整布局，留出顶部空间给title或者避免紧凑
plt.show()
